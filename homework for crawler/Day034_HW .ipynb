# %% [markdown]
# # 反爬：代理伺服器/IP
#
# * 了解「IP 黑/白名單」的反爬蟲機制
# * 「IP 黑/白名單」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 目前程式中的 proxy_ips 是手動輸入的，請根據 https://free-proxy-list.net/ 寫一個可自動化抓取可用 Proxy 的 proxy_ips。

# %%
from bs4 import BeautifulSoup
import requests
import random
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

proxy_ips = []

proxy_url = 'https://free-proxy-list.net/'
browser = webdriver.Chrome()
browser.get(proxy_url)  # 打開瀏覽器並連到網頁
time.sleep(2)  # delay一段時間等待網頁更新完成

# n = 0
while True:
    time.sleep(3)  # delay一段時間等待網頁更新完成
    html = browser.page_source
    soup = BeautifulSoup(html, 'lxml')
    table = soup.find(name = 'table',attrs = {'id':'proxylisttable'})
    tbody = table.find('tbody')
    
    for tr in tbody:
        ip = tr.td.string
        port = tr.td.next_sibling.string
        proxy_ips.append(ip + ':' + port)
#     print(proxy_ips)

    n += 1
    print(f'第{n}頁已爬完')

    for i in range(1):
        browser.find_element_by_xpath("//li[@class='fg-button ui-button ui-state-default next']/a").click()
        break

#     nextpage = browser.find_element_by_xpath("//li[@class='fg-button ui-button ui-state-default next']/a/disabled")
#     if nextpage is not None:
#         print(f'沒有下一頁了，共{n}頁')
#         break
#     else:
#         browser.find_element_by_xpath("//li[@class='fg-button ui-button ui-state-default next']/a").click()

# %%
print(proxy_ips)
# Out:
# ['46.39.41.21:8080', '91.220.166.148:39915', '195.190.100.90:8090', '95.0.35.227:8080', '94.138.104.2:51060', '5.160.72.146:55206', '175.41.44.43:52581', '166.150.32.184:43539', '87.103.211.189:3128', '148.251.200.192:1080', '103.12.161.194:59777', '190.52.193.97:63141', '217.30.64.26:53281', '124.41.213.201:33173', '192.162.62.197:59246', '34.244.2.233:8123', '175.139.179.65:39924', '103.66.176.93:51062', '103.38.102.182:59280', '212.200.27.134:8080', '190.97.209.74:60999', '85.52.217.114:33184', '212.142.226.229:39995', '174.127.155.118:32505', '77.72.124.246:1080', '43.225.67.39:53905', '202.152.38.75:52740', '125.27.251.87:58182', '80.65.28.57:30962', '5.9.202.167:1080', '181.52.85.249:36107', '183.88.213.25:54661', '176.119.134.171:23500', '125.26.99.212:51591', '154.119.79.254:53281', '101.51.141.49:57977', '31.216.188.107:46607', '171.101.22.204:8118', '103.49.221.27:8080', '36.255.234.243:60833', '151.253.158.2:8080', '36.72.114.20:8080', '194.44.172.254:23500', '186.219.210.86:33668', '180.241.131.84:8080', '36.89.183.241:60064', '181.129.140.226:47524', '103.109.98.218:44527', '103.92.212.33:43399', '163.53.198.54:42787', '46.173.105.151:41258', '109.74.142.138:53281', '160.119.131.114:34453', '94.74.184.109:80', '70.169.70.83:80', '113.28.129.60:80', '207.154.231.212:8080', '88.118.131.30:34850', '200.89.178.208:3128', '94.74.184.115:80', '181.30.28.14:8080', '46.18.202.159:50604', '94.74.190.107:80', '139.59.109.156:3128', '119.81.199.82:8123', '165.0.52.210:8080', '45.248.138.210:59714', '179.108.169.71:8080', '200.89.178.211:8080', '42.115.88.12:32728', '191.252.204.217:80', '200.89.178.210:8080', '5.141.244.28:8080', '62.160.163.237:8080', '94.74.149.97:80', '188.226.141.211:3128', '