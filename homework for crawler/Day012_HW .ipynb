# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html5lib')
for d in soup.find(class_ = 'part_list_2').find_all('h3'):
#     print(d.find(class_ = 'date').text, d.find_all('a')[-1].text)
    print(d.find(class_ = 'date').text, d.find('a').text)
# Out:
# 2019/12/15 15:31 平鎮王牌李晨薰赴美動韌帶移植手術　羅健銘：相信他能復出
# 2019/12/15 15:30 雷納德輪休　拉文準絕殺三分打終結快艇4連勝
# 2019/12/15 15:30 《天空之城》趙炳圭只稱讚大4歲朴恩玭！　南宮珉吃醋「連咳好幾聲」暗示…全場笑翻
# 2019/12/15 15:25 遠航爭復飛⋯交通部要「從嚴審查」　學者：三大層面說清楚才能過關
# 2019/12/15 15:24 網傳選舉奧步！讓韓粉票成廢票　民進黨：天方夜譚！造謠再添一筆
# 2019/12/15 15:20 忘記熄火！愛犬將車開進池塘　主人一臉懵懂傻在岸邊
# 2019/12/15 15:19 慘中果園捕獸鋏！三峽小獼猴蒼白依偎媽媽　來不及到醫院就離世
# 2019/12/15 15:18 小聯盟遭裁42隊千人失業群起反抗　大聯盟放話組新聯盟
# 2019/12/15 15:17 木瓜又大又香！她一見口水流滿地　下秒迅速往下塞...賊樣全被拍下慘賠1萬
# 2019/12/15 15:14 冬盟／黃柏豪、李凱威猛打賞開轟　味全7比0完封中職奪季軍
# 2019/12/15 15:12 從4歲到78歲都是高手　珠心算國際賽6國700選手桃園參賽
# 2019/12/15 15:12 男星演戲「台詞全是12345」！　超出戲影片流出網笑崩：真的演技派
# 2019/12/15 15:11 南投市民宅大火　女婿將岳父拖出屋外…他48%面積燒傷命危搶救中
# 2019/12/15 15:09 「事情沒做完就想請假」　裝病別以為不會被發現
# 2019/12/15 15:09 沒訂位吃不到！中壢無菜單日本料理　吃得到頂級松露粥
# 2019/12/15 15:04 華聞快遞／北京訂目標：遊戲產業2025年「年產值將達1500億」
# 2019/12/15 15:01 奈良縱火案！焦黑男屍非住戶「脖子帶刀痕」　火源住戶20天後自首
# 2019/12/15 15:01 完全預約制！屏東隱藏版景觀咖啡廳　還有峇里島風露天區能坐
# 2019/12/15 15:00 代號「禿子、蔬菜」！警破大選賭盤　「1對1」手機通訊軟體下注
# 2019/12/15 15:00 柯以柔曝人生卡關最嚴重的2年　痛訴離婚慘況「從小到大都沒想過」
# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
res = {} # 先把類別放進來

for d in soup.find(class_ = 'part_list_2').find_all('h3'):
    date = d.find(class_="date").text
    title = d.find('a').text
    tag = d.select('.tag')[0].text
    res.setdefault(tag, []) # 如果鍵不存在於字典中，將會添加鍵並將值設為默認值
    res[tag].append({
        'title': title,
        'date': date
    })
print(res)
# Out:
# {'體育': [{'title': '平鎮王牌李晨薰赴美動韌帶移植手術\u3000羅健銘：相信他能復出', 'date': '2019/12/15 15:31'}, {'title': '雷納德輪休\u3000拉文準絕殺三分打終結快艇4連勝', 'date': '2019/12/15 15:30'}, {'title': '小聯盟遭裁42隊千人失業群起反抗\u3000大聯盟放話組新聯盟', 'date': '2019/12/15 15:18'}, {'title': '冬盟／黃柏豪、李凱威猛打賞開轟\u3000味全7比0完封中職奪季軍', 'date': '2019/12/15 15:14'}, {'title': '國民眼看奪冠功臣蘭登出走\u3000鎖定MVP強打唐納森補三壘', 'date': '2019/12/15 14:40'}, {'title': '桌球年終賽／林昀儒領銜中華拿1銀2銅\u3000創近6年最佳成績', 'date': '2019/12/15 14:11'}, {'title': '桌球年終賽／林昀儒、廖振珽難跨中國障礙\u3000男雙摘銀追平隊史最佳', 'date': '2019/12/15 13:51'}, {'title': '高中鋁聯／平鎮豐收個人獎\u3000羅浩晨打擊三冠王', 'date': '2019/12/15 13:50'}, {'title': '中職／林政賢隨隊、羅嘉仁等合約\u3000味全春訓時間公布', 'date': '2019/12/15 13:46'}, {'title': '公鹿17分宰騎士18連勝\u30002015-16勇士24連勝後最長', 'date': '2019/12/15 13:44'}, {'title': '高中鋁聯／鶯歌2比1勝大理奪季軍\u3000破去年再創隊史最佳', 'date': '2019/12/15 13:39'}, {'title': '冬盟／吊車尾加入職棒！魏全進步多\u3000成葉君璋最意外球員', 'date': '2019/12/15 13:30'}, {'title': '冬盟／林威助肯定選手態度\u3000比賽差在小細節', 'date': '2019/12/15 13:12'}, {'title': '冬盟／喜歡味全想回來！川崎宗則分析台日球員差異\
# ...

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
result = [] # 先把類別放進來
result2 = {} # 整理各類別有多少個
for tags in soup.find(class_ = 'part_list_2').find_all('h3'):
    result.append(tags.find_all('em')[-1].text)

for tag in result:
    if tag not in result2:
        result2[tag] = 1
    else:
        result2[tag] += 1
print(result2)
print(max(result2, key = result2.get))

# reference: [Find most frequent value in Python dictionary](https://stackoverflow.com/questions/48606406/find-most-frequent-value-in-python-dictionary-value-with-maximum-count)
# Out:
# {'體育': 20, '影劇': 14, '生活': 10, '政治': 4, '寵物動物': 2, '社會': 13, '地方': 6, '時尚': 5, '旅遊': 4, '大陸': 3, '國際': 6, '房產雲': 4, '財經': 5, '健康': 2, 'ET車雲': 1, '探索': 1}
# 體育
